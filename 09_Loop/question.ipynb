# %%
customers = '토끼', '곰', '여우', '호랑이'
for i in customers:
    print(f"안녕하세요 {i}님")
# Out:
# 안녕하세요 토끼님
# 안녕하세요 곰님
# 안녕하세요 여우님
# 안녕하세요 호랑이님

# %%
orders = '아메리카노', '카페라떼', '핫초코'
for x in orders:
    print(f"{x}를 준비")
# Out:
# 아메리카노를 준비
# 카페라떼를 준비
# 핫초코를 준비

# %%
tables = 1,2,3,4,5
for x in tables:
    print(f"{x} 번 테이블 청소 완료")
# Out:
# 1 번 테이블 청소 완료
# 2 번 테이블 청소 완료
# 3 번 테이블 청소 완료
# 4 번 테이블 청소 완료
# 5 번 테이블 청소 완료

# %%
for x in range(9,13):
    print(f"현재 시간 {x}시 근무 기록")
# Out:
# 현재 시간 9시 근무 기록
# 현재 시간 10시 근무 기록
# 현재 시간 11시 근무 기록
# 현재 시간 12시 근무 기록

# %%
for x in range(1,11):
    print(f"손님 {x}번쨰 입장")
# Out:
# 손님 1번쨰 입장
# 손님 2번쨰 입장
# 손님 3번쨰 입장
# 손님 4번쨰 입장
# 손님 5번쨰 입장
# 손님 6번쨰 입장
# 손님 7번쨰 입장
# 손님 8번쨰 입장
# 손님 9번쨰 입장
# 손님 10번쨰 입장

# %%
for x in range(1,6):
    print(f"{x}번쨰 커피 만드는중")
# Out:
# 1번쨰 커피 만드는중
# 2번쨰 커피 만드는중
# 3번쨰 커피 만드는중
# 4번쨰 커피 만드는중
# 5번쨰 커피 만드는중

# %%
i = 1

while i <= 5:
    print(f"{i}번 테이블 청소")
    i += 1
# Out:
# 1번 테이블 청소
# 2번 테이블 청소
# 3번 테이블 청소
# 4번 테이블 청소
# 5번 테이블 청소

# %%
customers = 5
while customers >= 0:
    print(f"남은 손님 수 : {customers}명")
    customers-=1
    if customers == -1:
        print("영업 끝")
# Out:
# 남은 손님 수 : 5명
# 남은 손님 수 : 4명
# 남은 손님 수 : 3명
# 남은 손님 수 : 2명
# 남은 손님 수 : 1명
# 남은 손님 수 : 0명
# 영업 끝

# %%
work_hours = int(input("일한 시간"))
pay = 0
i = 1
while work_hours > 0:
    pay += 1000
    work_hours =- 1

print(f"오늘의 알바비는", {pay}, "원입니다.")
# Out:
# 오늘의 알바비는 {1000} 원입니다.
