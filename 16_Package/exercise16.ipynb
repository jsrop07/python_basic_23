# %%
import mowai.team.teacher_module as mtt

print(mtt.gorilla())
print(mtt.ohgiraffers_team)
# Out:
# 크왕
# 국내최고 IT 전문교육 강사팀

# %%
from mowai.team import teacher_module as mtt
print(mtt.ohgiraffers_team)
print(mtt.pig())
# Out:
# 국내최고 IT 전문교육 강사팀
# 꿀꿀

# %%
# 설치된 라이브러리 확인

# !pip freeze > requirements.txt

# %%
# 패키지 문제

# %%
from work_management import task_tracking as task

print(task.start_task('asd'))
# Out:
# asd 시작됨

# %%
from schedule_management import calendar as ca
from datetime import datetime

now = datetime.now()
nownow = now.replace(second=0,microsecond=0)
print(ca.add_event('회식',nownow))
print(ca.remove_event( '회식'))
# Out:
# 2025-11-28 14:19:00에 회식 일정이 추가
# 회식 일정이 삭제

# %%
import numpy
test = [1,2,3]
print(numpy.mean(test))
# Out:
# 2.0

# %%
f = open('C:\\Users\\Playdata\\PYTHON\\newfile.txt','w')
