# %%
input_s = input('서울에 갈 계획이 있나여 (y/n) : ')
if input_s == 'y':
    print('서울로 간다!')
# Out:
# 서울로 간다!

# %%
input_s = input('집에 있는 가구를 다 가져갈까요? (y/n) : ')
if input_s == 'n':
    print('서울에서 가구를 새로 산다.!')
# Out:
# 서울에서 가구를 새로 산다.!

# %%
input_s = input('오늘 서울 날씨는 맑음인가요? (y/n) : ')
if input_s == 'y':
    print('서울구경.!')
else:
    print('집')
# Out:
# 집

# %%
input_s = int(input('월세 예산은 얼마인가요 : '))
if input_s <= 1000000 :
    print('고시원에서 .!')
else:
    print('원룸을 ')
# Out:
# 고시원에서 .!

# %%
input_s = input('원하는 직장 종류(프리랜서/중소기업/대기업) : ')
if input_s == '프리랜서' :
    print('시간은 자유롭지만 불안정하다')
elif input_s == '중소기업':
    print('정적이지만 일이 많다. ')
else:
    print('좋은 직장스')
# Out:
# 좋은 직장스

# %%
input_s = int(input('아침에 일어나는 시간을 입력하세요 :  '))
wake_time = 0
match input_s:
    case 6:
        print('운동을 한다')
    case 7:
        print('공부')
    case 8:
        print('출근')

# %%
input_s = input('오늘 날씨가 어떤가요? (맑음/비/눈): ')
# match input_s:
#     case '맑음':
#         print('한강')
#     case '비':
#         print('asmr')
#     case '눈':
#         print('귤')
#     case _:
#         print('럭키비키')

result = (
    '한강 ' if input_s == '맑음' else
    '집에서 빗소리' if input_s =="비" else
    '전기장판' if input_s == "눈" else
    '푹 자자'
)
print(type(result))
# Out:
# <class 'str'>

# %%
# input_s = int(input('소지금 얼마? :'))
# print('기차표를 구매했다' if input_s >=50000 else '컷')
input_s = int(input('소지금 얼마? :'))
x =50000
match input_s>=x:
    case  True:
        print("기차표를 구매했다!")
    case _:
        print("기차표를 구매실패!")
# Out:
# rnf
