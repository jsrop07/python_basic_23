# %%
123
# Out:
# 123

# %%
print(123)
# Out:
# 123

# %%
num -1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 num -1
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
num = 1

# %%
num
# Out:
# 1

# %%
print(num)
# Out:
# 1

# %%
num = "1"
print(num)
# Out:
# 1

# %%
team_name="mowai"
my_team = team_name
print(my_team)
# Out:
# mowai

# %% [markdown]
# 좌항은 변수명, 우항은 원시 문자열로 표현된 자료

# %%
-- alt + shift + 마우스 -> 특정 구간 드래그로 복사 
-- alt + shift + 아래 -> 줄 복사

# %%
team_name = "mowai"
my_team = team_name
team_name = "mowaiwwhy"



print("team_name", team_name)
print("my_team", my_team)
# Out:
# team_name mowaiwwhy
# my_team mowai

# %%
x = 5
y = x
x = 10
print(y)
# Out:
# 5

# %%
team_name = 'mowai-23'
print(team_name)

Team_name = 'sk-23'
print(team_name)
print(Team_name)

# camelCase는 자바나 자바스크립트에서 자주 사용
# Out:
# mowai-23
# mowai-23
# sk-23

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
print(_)
# Out:
# 123

# %%
10
# Out:
# 10

# %%
print(_)
print(_ * 3)
# Out:
# 10
# 30

# %%
x,_,z = (1,2,3)
print(x)
print(_)
# Out:
# 1
# 2

# %%
# 코딩에서 *는 모든것이란 뜻

x,*_,y = (1,2,3,4,8)
print(_)
# Out:
# [2, 3, 4]

# %%
for _ in range(3):
    print(_)
# Out:
# 0
# 1
# 2

# %%
# private와 동일한 기능은 아니지만 private함수처럼 변수로 선언해서 사용할 수 있다 
_internal_name = 'one_module'
