# %%
# 1-1번 
name = "정석원"

# 1-2번
age = 27

print(name)
print(age)
# Out:
# 정석원
# 27

# %%
# 2-1번
height = "250"
dream = "부자"
print(height,"\n",dream)
# Out:
# 250
#  부자

# %%
# 문제 3
city  =  "분당"
my_city = city
print(my_city)
print(city)
# Out:
# 분당
# 분당

# %%
# 문제 4
apple_count = 10
orange_count = 20
print(apple_count)
print(orange_count)
# Out:
# 10
# 20

# %%
# 문제 5
first_name = "정"
last_name  = "석원"

full_name = first_name + last_name

print(first_name, "\n", last_name)
print(full_name)
# Out:
# 정
#  석원
# 정석원
