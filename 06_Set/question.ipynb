# %%
fruits = {'apple', 'banana', 'cherry'}

# %%
print(type(fruits))
# Out:
# <class 'set'>

# %%
animals = {'cat', 'dog', 'bird', 'fish'}
animals.remove('bird')

# %%
set1 = {1,2,3}
set2 ={3,4,5}

# %%
set1 |set2
# Out:
# {1, 2, 3, 4, 5}

# %%
student = {'name' : 'John', 'age': 20, 'major' : 'Compoter'}
student['age']
# Out:
# 20

# %%
scores =  {'math': 80, 'english': 90}
scores['math']= 95
scores
# Out:
# {'math': 95, 'english': 90}

# %%
colors1 = {'red', 'blue', 'green'}
colors2 = { 'blue', 'yellow', 'pink'}
colors1 & colors2
# Out:
# {'blue'}

# %%
method = {'name': 'Alice', 'age': 25, 'city': 'Seoul'}
print(method.keys())
print(method.values())
# Out:
# dict_keys(['name', 'age', 'city'])
# dict_values(['Alice', 25, 'Seoul'])

# %%
students = {'student1': 85, 'student2': 90, 'student3': 95}
students.pop('student2')
# Out:
# 90

# %%
students
# Out:
# {'student1': 85, 'student3': 95}

# %%
numbers = {1,2,3,4,5}
type(numbers)
# Out:
# set

# %%
# 문제 9번

# squares = {
#     1 : numbers[0] * numbers[0],
#     2 : numbers[1] * numbers[1],
#     3 : numbers[3] * numbers[3]
# }

squares = {}

for num in numbers:
    squares[num] = num**2

squares
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}
A ^ B
# Out:
# {1, 2, 5, 6}
