# %%
num1 = 1
num2 = -1
num3 = 3.15
num4 =1.0
num5 =3+4j
print(type(num1))
print(type(num2))
print(type(num3))
print(type(num4))
print(type(num5))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'complex'>

# %%
import sys
print(sys.maxsize)
# Out:
# 9223372036854775807

# %%
# 특수
# 4.2410e => 4.24 * 10*10 
a = 4.24e3
b = 4.24e-3

print(a)
print(b)
# Out:
# 4240.0
# 0.00424

# %%
num1 = 10
num2 = 3
print(num1+num2)
print(num1-num2)
print(num1*num2)
print(num1/num2)
# Out:
# 13
# 7
# 30
# 3.3333333333333335

# %%
num3=10
num4=0.1
print(num3+num4)
print(num3-num4)
print(num3*num4)
print(num3/num4)
# Out:
# 10.1
# 9.9
# 1.0
# 100.0

# %%
num5 = 11
num6 =7
print(num5%num6)
# Out:
# 4

# %%
num5 = 11
num6 =7
print(num5 // num6)
# Out:
# 1

# %%
base = 9
exponent = 2

print(base** exponent)
print(exponent ** base)
# Out:
# 81
# 512

# %%
bool1 = True
bool2 = False
print(type(bool1))
print(type(bool2))
# Out:
# <class 'bool'>
# <class 'bool'>

# %%
print(1 == 3)
# Out:
# False

# %%
print(int('0') > 0)
# Out:
# False

# %%
print("hello printf is pjp language " + ("phphphp" + "ajsdsad")*3)
# Out:
# hello printf is pjp language phphphpajsdsadphphphpajsdsadphphphpajsdsad

# %%
date = '2025/11/25'
enroll_date = date.split("5")
print(enroll_date)
# Out:
# ['202', '/11/2', '']

# %%
origin = "mowaii"
new_origin = "     mowaii"
print(new_origin)
print(new_origin.strip())
print(new_origin.strip('  m'))
print(origin.strip('ow'))
print(origin.lstrip('mi'))
print(origin.rstrip('mi'))
# Out:
#      mowaii
# mowaii
# owaii
# mowaii
# owaii
# mowa

# %%
team_name = "mowai"
print(f"안녕하세요 우리는 {team_name}")
# Out:
# 안녕하세요 우리는 mowai

# %%
name = "카피바라"
print(str(900) + "살" + name)
# Out:
# 900살카피바라

# %%
origin_str = "heLLO OWorld"
print(origin_str.capitalize())
print(origin_str.swapcase())
print(origin_str.upper())
print(origin_str.lower())
print(origin_str.title())
# Out:
# Hello oworld
# HEllo owORLD
# HELLO OWORLD
# hello oworld
# Hello Oworld

# %%
x = 10
y = "code "
k = "l"
print("x is %d" %x)
print("y is %s" %y)
print("k is %c" %k)
# Out:
# y is code
# k is l
# x is 10

# %%
x,y = 10, "code"
print("x is {0}".format(x))
print("x is {0} y is {1}".format(x,y))
print("x is {new_x} and y is {new_y}".format(new_x = x, new_y =y))
# Out:
# x is 10
# x is 10 y is code
# x is 10 and y is code

# %%
print(True + 3)
print(3 + 5.0)
print(type(True + 3))
print(type(3 + 5.0))
print(int('4')+3)
print(float('4')+3)
# Out:
# 4
# 8.0
# <class 'int'>
# <class 'float'>
# 7
# 7.0

# %%
print(list("mowail"))
# Out:
# ['m', 'o', 'w', 'a', 'i', 'l']

# %%
print(list({1,2,3,4}))
# Out:
# [1, 2, 3, 4]

# %%
print(list({
    "1" : "asd",
    "2" : "asasdd",
    "3" : "cxzxczxc"
}))
# Out:
# ['1', '2', '3']
