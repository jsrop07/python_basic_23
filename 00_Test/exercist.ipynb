# %%
import testst

print(testst.record_attendance('석원','3'))
# Out:
# 석원,3

# %%
import math

daily =  [10,12,8,15,9]

average = sum(daily)/ len(daily)

print(int(average))
count = 0
for i in daily:
    if(i>average):
        count+=1
print(count)
# Out:
# 10
# 2
